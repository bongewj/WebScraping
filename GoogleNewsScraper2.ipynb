# %%
import warnings
warnings.simplefilter('ignore')

# %%
import scrapy
from scrapy.utils.project import get_project_settings
from scrapy.crawler import CrawlerProcess
import os

if os.path.exists("D:\Kaggle Data Sets\Jupyter Folder\ScrapyProjects\ScrapyTest\ScrapyTest\GNewsSembMarine.json"):
    os.remove("D:\Kaggle Data Sets\Jupyter Folder\ScrapyProjects\ScrapyTest\ScrapyTest\GNewsSembMarine.json")
    print("SembMarine file is removed")

if os.path.exists("D:\Kaggle Data Sets\Jupyter Folder\ScrapyProjects\ScrapyTest\ScrapyTest\GNewsEcon.json"):
    os.remove("D:\Kaggle Data Sets\Jupyter Folder\ScrapyProjects\ScrapyTest\ScrapyTest\GNewsEcon.json")
    print("Economy file is removed")

if os.path.exists("D:\Kaggle Data Sets\Jupyter Folder\ScrapyProjects\ScrapyTest\ScrapyTest\GNewsEnergy.json"):
    os.remove("D:\Kaggle Data Sets\Jupyter Folder\ScrapyProjects\ScrapyTest\ScrapyTest\GNewsEnergy.json")
    print("Energy file is removed") 

if os.path.exists("D:\Kaggle Data Sets\Jupyter Folder\ScrapyProjects\ScrapyTest\ScrapyTest\GNewsMarine.json"):
    os.remove("D:\Kaggle Data Sets\Jupyter Folder\ScrapyProjects\ScrapyTest\ScrapyTest\GNewsMarine.json")
    print("Marine file is removed")   

if os.path.exists("D:\Kaggle Data Sets\Jupyter Folder\ScrapyProjects\ScrapyTest\ScrapyTest\GNewsOffshore.json"):
    os.remove("D:\Kaggle Data Sets\Jupyter Folder\ScrapyProjects\ScrapyTest\ScrapyTest\GNewsOffshore.json")
    print("Offshore file is removed")  

process = CrawlerProcess(get_project_settings())
process.crawl('GNewsSembMarine')
process.crawl('GNewsEnergy')
process.crawl('GNewsEcon')
process.crawl('GNewsMarine')
process.crawl('GNewsOffshore')
process.start()
# Out:
# 2021-11-06 21:52:53 [scrapy.utils.log] INFO: Scrapy 2.4.1 started (bot: ScrapyTest)
# 2021-11-06 21:52:53 [scrapy.utils.log] INFO: Versions: lxml 4.6.3.0, libxml2 2.9.12, cssselect 1.1.0, parsel 1.5.2, w3lib 1.21.0, Twisted 21.2.0, Python 3.9.0 (default, Nov 15 2020, 08:30:55) [MSC v.1916 64 bit (AMD64)], pyOpenSSL 21.0.0 (OpenSSL 1.1.1l  24 Aug 2021), cryptography 35.0.0, Platform Windows-10-10.0.19041-SP0
# 2021-11-06 21:52:53 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.selectreactor.SelectReactor
# 2021-11-06 21:52:53 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'ScrapyTest',
#  'CONCURRENT_REQUESTS': 8,
#  'DOWNLOAD_DELAY': 5,
#  'NEWSPIDER_MODULE': 'ScrapyTest.spiders',
#  'SPIDER_MODULES': ['ScrapyTest.spiders'],
#  'USER_AGENT': 'Mozilla/5.0 (Windows NT 10.0) AppleWebKit/537.36 (KHTML, like '
#                'Gecko) Chrome/42.0.2311.135 Safari/537.36 Edge/12.10136'}
# ...
